# %% [markdown]
# # 期权示例

# %%
import optshare

# %% [markdown]
# ## 获取期权数据

# %% [markdown]
# ### 返回当前场内期权数据

# %%
optshare.get_current_option()
# Out:
#                  代码              名称    最新价    涨跌额      涨跌幅     成交量  \
# 0      cu2305P53000  沪铜23年05月沽53000  46.00  44.00  2200.00    29.0
# 1         i2306p530   铁矿石23年06月沽530   1.70   1.60  1600.00     1.0
# 2         i2306p520   铁矿石23年06月沽520   1.50   1.40  1400.00     1.0
# 3      cu2304C82000  沪铜23年04月购82000  30.00  28.00  1400.00   121.0
# 4        v2305c8000  PVC23年05月购8000   6.50   6.00  1200.00  1239.0
# ...             ...             ...    ...    ...      ...     ...
# 11043    sc2303P520    原油23年03月沽520   0.75  -7.25   -90.63  7907.0
# 11044    sc2303P490    原油23年03月沽490   0.05  -0.65   -92.86  1389.0
# 11045    sc2303P510    原油23年03月沽510   0.25  -3.95   -94.05  4856.0
# 11046    sc2303P500    原油23年03月沽500   0.10  -1.80   -94.74  5613.0
# 11047    sc2303P495    原油23年03月沽495   0.05  -1.15   -95.83   837.0
#
#               成交额     持仓量  行权价  剩余日     日增   昨结     今开
# 0          7210.0   332.0  NaN  NaN    9.0  2.0  46.00
# 1           170.0     5.0  NaN  NaN    0.0  0.1   1.70
# 2           150.0     6.0  NaN  NaN    0.0  0.1   1.50
# 3         16400.0   208.0  NaN  NaN  -18.0  2.0  34.00
# 4         40792.0  3964.0  NaN  NaN  193.0  0.5   7.50
# ...           ...     ...  ...  ...    ...  ...    ...
# 11043  21047400.0  1367.0  NaN  NaN  633.0  8.0   3.80
# 11044    191250.0   955.0  NaN  NaN   19.0  0.7   0.25
# 11045   5168150.0  1303.0  NaN  NaN  525.0  4.2   1.80
# 11046   2359600.0  2105.0  NaN  NaN  655.0  1.9   0.85
# 11047    239650.0   251.0  NaN  NaN   24.0  1.2   0.45
#
# [11048 rows x 13 columns]

# %% [markdown]
# ### 指定交易所名称，返回当前交易所的期权数据

# %%
optshare.get_current_option(exchange_name = 'cffex')
# Out:
#                 代码                名称  最新价   涨跌额      涨跌幅   成交量        成交额  \
# 0    HO2302-P-2350    上证50沽23年2月2350  0.6   0.4   200.0%     9      420.0
# 1    MO2302-P-5500  中证1000沽23年2月5500  0.4   0.2   100.0%    13      400.0
# 2    MO2302-P-5600  中证1000沽23年2月5600  0.4   0.2   100.0%    27      900.0
# 3    IO2302-P-3350   沪深300沽23年2月3350  0.4   0.2   100.0%     3      120.0
# 4    MO2302-P-5900  中证1000沽23年2月5900  0.6   0.2    50.0%    35     1600.0
# ..             ...               ...  ...   ...      ...   ...        ...
# 671  IO2302-C-4350   沪深300购23年2月4350  1.0  -1.4  -58.33%   830   138680.0
# 672  MO2302-C-7100  中证1000购23年2月7100  9.8 -16.6  -62.88%  3206  5568220.0
# 673  MO2302-C-7200  中证1000购23年2月7200  3.8  -8.8  -69.84%  1560  1338480.0
# 674  MO2302-C-7400  中证1000购23年2月7400  0.8  -2.2  -73.33%   214    31920.0
# 675  MO2302-C-7300  中证1000购23年2月7300  1.6  -4.6  -74.19%   694   300580.0
#
#       持仓量     行权价  剩余日   日增    昨结    今开
# 0      26  2350.0    9    3   0.2   0.6
# 1     148  5500.0    9   -5   0.2   0.4
# 2     219  5600.0    9   -9   0.2   0.4
# 3     230  3350.0    9    0   0.2   0.4
# 4     227  5900.0    9    0   0.4   0.4
# ..    ...     ...  ...  ...   ...   ...
# 671  2284  4350.0    9 -114   2.4   2.6
# 672  1965  7100.0    9   -9  26.4  26.2
# 673  1233  7200.0    9    7  12.6  12.2
# 674  1026  7400.0    9  -69   3.0   2.8
# 675   657  7300.0    9 -106   6.2   6.4
#
# [676 rows x 13 columns]

# %% [markdown]
# ### 根据挂钩标的代码，返回当前挂钩该标的的期权信息

# %%
# 权益类
optshare.get_current_option(underlying_code ='000300')
# Out:
#                 代码               名称    最新价   涨跌额      涨跌幅   成交量         成交额  \
# 0    IO2302-P-3350  沪深300沽23年2月3350    0.4   0.2   100.0%     3       120.0
# 1    IO2303-P-3100  沪深300沽23年3月3100    1.0   0.2    25.0%    22      2180.0
# 2    IO2302-P-4150  沪深300沽23年2月4150   89.0   8.2   10.15%  3847  31535060.0
# 3    IO2302-P-4050  沪深300沽23年2月4050   30.8   2.8    10.0%  5442  14995660.0
# 4    IO2302-P-4200  沪深300沽23年2月4200  129.6  10.8    9.09%  2643  32651780.0
# ..             ...              ...    ...   ...      ...   ...         ...
# 259  IO2302-P-3550  沪深300沽23年2月3550    0.2  -0.2   -50.0%   125      3160.0
# 260  IO2302-C-4250  沪深300购23年2月4250    3.8  -4.0  -51.28%  2124   1199480.0
# 261  IO2302-C-4300  沪深300购23年2月4300    2.0  -2.4  -54.55%  2072    570340.0
# 262  IO2302-P-3800  沪深300沽23年2月3800    0.8  -1.0  -55.56%   457     47040.0
# 263  IO2302-C-4350  沪深300购23年2月4350    1.0  -1.4  -58.33%   830    138680.0
#
#       持仓量     行权价  剩余日   日增     昨结     今开
# 0     230  3350.0    9    0    0.2    0.4
# 1     437  3100.0   37  -13    0.8    0.8
# 2    3034  4150.0    9 -119   80.8   77.0
# 3    2799  4050.0    9 -109   28.0   23.8
# 4    2791  4200.0    9 -509  118.8  115.0
# ..    ...     ...  ...  ...    ...    ...
# 259   291  3550.0    9  -58    0.4    0.4
# 260  3969  4250.0    9  -68    7.8    8.2
# 261  5170  4300.0    9 -841    4.4    4.8
# 262  1338  3800.0    9 -177    1.8    1.0
# 263  2284  4350.0    9 -114    2.4    2.6
#
# [264 rows x 13 columns]

# %%
# 商品类，以铜期权为例
optshare.get_current_option(underlying_code ='cu')
# Out:
#                代码              名称    最新价    涨跌额      涨跌幅   成交量        成交额  \
# 0    cu2305P53000  沪铜23年05月沽53000   46.0   44.0  2200.0%     4     7210.0
# 1    cu2304C82000  沪铜23年04月购82000   30.0   28.0  1400.0%    41    16400.0
# 2    cu2304P56000  沪铜23年04月沽56000   24.0   22.0  1100.0%     1      730.0
# 3    cu2303C76000  沪铜23年03月购76000   22.0   20.0  1000.0%   165    64070.0
# 4    cu2303C75000  沪铜23年03月购75000   42.0   38.0   950.0%   599   340790.0
# ..            ...             ...    ...    ...      ...   ...        ...
# 347  cu2303P68000  沪铜23年03月沽68000  508.0 -532.0  -51.15%  1027  8867910.0
# 348  cu2303P64000  沪铜23年03月沽64000   26.0  -36.0  -58.06%  1131   642570.0
# 349  cu2303P65000  沪铜23年03月沽65000   62.0  -90.0  -59.21%  2894  3455700.0
# 350  cu2303P67000  沪铜23年03月沽67000  238.0 -372.0  -60.98%  1498  6262470.0
# 351  cu2303P66000  沪铜23年03月沽66000  118.0 -204.0  -63.35%  2701  5483850.0
#
#       持仓量  行权价  剩余日   日增      昨结     今开
# 0     332  NaN  NaN    9     2.0   46.0
# 1     208  NaN  NaN  -18     2.0   34.0
# 2      94  NaN  NaN    5     2.0   20.0
# 3     752  NaN  NaN  120     2.0   26.0
# 4    2808  NaN  NaN  347     4.0   42.0
# ..    ...  ...  ...  ...     ...    ...
# 347  1521  NaN  NaN   97  1040.0  830.0
# 348  1811  NaN  NaN  295    62.0   58.0
# 349  2977  NaN  NaN  164   152.0  100.0
# 350  1383  NaN  NaN   -4   610.0  422.0
# 351  3007  NaN  NaN  467   322.0  202.0
#
# [352 rows x 13 columns]

# %% [markdown]
# ## Option information

# %% [markdown]
# ### 支持的交易所名称以及字母简写

# %%
optshare.get_exchange_info()
# Out:
#   交易市场名称  交易市场
# 0    sse   上交所
# 1   szse   深交所
# 2  cffex   中金所
# 3   shfe   上期所
# 4    dce   大商所
# 5   czce   郑商所
# 6    ine  上期能源

# %% [markdown]
# ## 支持的期权品种

# %%
optshare.get_option_info()
# Out:
#       标的代码        期权名称
# 0   510050   上证50ETF期权
# 1   510300  沪深300ETF期权
# 2   510500  中证500ETF期权
# 3   159919  沪深300ETF期权
# 4   159922  中证500ETF期权
# 5   159915    创业板ETF期权
# 6   000300   沪深300股指期权
# 7   000852  中证1000股指期权
# 8   000016    上证50股指期权
# 9       cu         铜期权
# 10      al         铝期权
# 11      zn         锌期权
# 12      rb       螺纹钢期权
# 13      au        黄金期权
# 14      ag        白银期权
# 15      ru        天胶期权
# 16       m        豆粕期权
# 17       c        玉米期权
# 18       i       铁矿石期权
# 19      pg   液化石油天然气期权
# 20       l       聚乙烯期权
# 21       v      聚氯乙烯期权
# 22      pp       聚丙烯期权
# 23       p       棕榈油期权
# 24       a     黄大豆1号期权
# 25       b     黄大豆2号期权
# 26       y        豆油期权
# 27      SR        白糖期权
# 28      CF        棉花期权
# 29      TA       PTA期权
# 30      MA        甲醇期权
# 31      RM       菜籽粕期权
# 32      OI       菜籽油期权
# 33      PK        花生期权
# 34      sc        原油期权

# %% [markdown]
# ## 根据交易所名称，返回相应的期权信息

# %%
optshare.get_meta_data()
# Out:
#       标的代码        期权名称 交易市场名称  交易市场
# 0   510050   上证50ETF期权    sse   上交所
# 1   510300  沪深300ETF期权    sse   上交所
# 2   510500  中证500ETF期权    sse   上交所
# 3   159919  沪深300ETF期权   szse   深交所
# 4   159922  中证500ETF期权   szse   深交所
# 5   159915    创业板ETF期权   szse   深交所
# 6   000300   沪深300股指期权  cffex   中金所
# 7   000852  中证1000股指期权  cffex   中金所
# 8   000016    上证50股指期权  cffex   中金所
# 9       cu         铜期权   shfe   上期所
# 10      al         铝期权   shfe   上期所
# 11      zn         锌期权   shfe   上期所
# 12      rb       螺纹钢期权   shfe   上期所
# 13      au        黄金期权   shfe   上期所
# 14      ag        白银期权   shfe   上期所
# 15      ru        天胶期权   shfe   上期所
# 16       m        豆粕期权    dce   大商所
# 17       c        玉米期权    dce   大商所
# 18       i       铁矿石期权    dce   大商所
# 19      pg   液化石油天然气期权    dce   大商所
# 20       l       聚乙烯期权    dce   大商所
# 21       v      聚氯乙烯期权    dce   大商所
# 22      pp       聚丙烯期权    dce   大商所
# 23       p       棕榈油期权    dce   大商所
# 24       a     黄大豆1号期权    dce   大商所
# 25       b     黄大豆2号期权    dce   大商所
# 26       y        豆油期权    dce   大商所
# 27      SR        白糖期权   czce   郑商所
# 28      CF        棉花期权   czce   郑商所
# 29      TA       PTA期权   czce   郑商所
# 30      MA        甲醇期权   czce   郑商所
# 31      RM       菜籽粕期权   czce   郑商所
# 32      OI       菜籽油期权   czce   郑商所
# 33      PK        花生期权   czce   郑商所
# 34      sc        原油期权    ine  上期能源

# %% [markdown]
# ## 根据交易所名称，返回相应的期权信息

# %%
optshare.get_meta_data(exchange_name = 'cffex')
# Out:
#      标的代码        期权名称 交易市场名称 交易市场
# 6  000300   沪深300股指期权  cffex  中金所
# 7  000852  中证1000股指期权  cffex  中金所
# 8  000016    上证50股指期权  cffex  中金所
